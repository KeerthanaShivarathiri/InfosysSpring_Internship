# %%
import gspread
from google.oauth2.service_account import Credentials

key = "AIzaSyCugbv2tcMzABN6u_BY7sWI_nM0RSCvED4"
# gc = gspread.api_key(key)  # This line is not needed and might cause issues

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
     "/content/infosysai-a91096bde79d.json",
     scopes=scopes
 )

gc = gspread.authorize(credentials)
sh = gc.open_by_key("1jtgQRDj3kvcVfJfL0fkFD0_VG9PRfjnnS7Caj8LBXpw")

# %%
import pandas as pd

worksheet = sh.sheet1 # or sh.get_worksheet(0) for the first sheet

# Get all values from the worksheet
data = worksheet.get_all_values()

# Convert to DataFrame
df = pd.DataFrame(data[1:], columns=data[0])  # First row is header

df.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 2  1024619926727    Exchange Request for Malfunctioning Dell XPS 13
# 3  1026487543175       Request for Server Administration Assistance
# 4  1027850274374   Immediate Attention Required: AWS Outage Concern
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 2  Dear Tech Online Store Customer Support,\n\n\n...
# 3  Dear IT Services Customer Support, \n\n\nWe ar...
# 4  Greetings IT Services Customer Support,\n\n\nI...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 2  Dear <name>,\n\n\nThank you for reaching out a...    Change
# 3  Subject: Re: Request for Server Administration...   Request
# 4  Hello <name>,\n\n\nWe appreciate you informing...  Incident
#
#                    queue priority language      business_type  \
# 0      Technical Support     high       en        IT Services
# 1        Product Support      low       en  Tech Online Store
# 2  Returns and Exchanges   medium       en  Tech Online Store
# 3        Product Support   medium       en        IT Services
# 4      Technical Support     high       en        IT Services
#
#                    tag_1                tag_2               tag_3  \
# 0         Service Outage        Network Issue        Urgent Issue
# 1      Technical Support      Product Support    Hardware Failure
# 2  Returns and Exchanges  Product Replacement    Customer Service
# 3      Technical Support           IT Support  Performance Tuning
# 4         Service Outage         Urgent Issue          IT Support
#
#                 tag_4               tag_5             tag_6  \
# 0   Technical Support  Problem Resolution  Critical Failure
# 1  Problem Resolution        Urgent Issue  Service Recovery
# 2   Technical Support         Order Issue
# 3  Problem Resolution  Technical Guidance  Service Recovery
# 4  System Maintenance     Incident Report  Customer Service
#
#                    tag_7               tag_8 tag_9 escalated escalation_score
# 0           System Crash  Service Disruption            TRUE                3
# 1  Documentation Request                               FALSE                1
# 2                                                      FALSE                0
# 3                                                      FALSE                0
# 4                                                       TRUE                2

# %%
df_en = df.loc[df["language"].eq("en"), :]
df_en.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 2  1024619926727    Exchange Request for Malfunctioning Dell XPS 13
# 3  1026487543175       Request for Server Administration Assistance
# 4  1027850274374   Immediate Attention Required: AWS Outage Concern
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 2  Dear Tech Online Store Customer Support,\n\n\n...
# 3  Dear IT Services Customer Support, \n\n\nWe ar...
# 4  Greetings IT Services Customer Support,\n\n\nI...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 2  Dear <name>,\n\n\nThank you for reaching out a...    Change
# 3  Subject: Re: Request for Server Administration...   Request
# 4  Hello <name>,\n\n\nWe appreciate you informing...  Incident
#
#                    queue priority language      business_type  \
# 0      Technical Support     high       en        IT Services
# 1        Product Support      low       en  Tech Online Store
# 2  Returns and Exchanges   medium       en  Tech Online Store
# 3        Product Support   medium       en        IT Services
# 4      Technical Support     high       en        IT Services
#
#                    tag_1                tag_2               tag_3  \
# 0         Service Outage        Network Issue        Urgent Issue
# 1      Technical Support      Product Support    Hardware Failure
# 2  Returns and Exchanges  Product Replacement    Customer Service
# 3      Technical Support           IT Support  Performance Tuning
# 4         Service Outage         Urgent Issue          IT Support
#
#                 tag_4               tag_5             tag_6  \
# 0   Technical Support  Problem Resolution  Critical Failure
# 1  Problem Resolution        Urgent Issue  Service Recovery
# 2   Technical Support         Order Issue
# 3  Problem Resolution  Technical Guidance  Service Recovery
# 4  System Maintenance     Incident Report  Customer Service
#
#                    tag_7               tag_8 tag_9 escalated escalation_score
# 0           System Crash  Service Disruption            TRUE                3
# 1  Documentation Request                               FALSE                1
# 2                                                      FALSE                0
# 3                                                      FALSE                0
# 4                                                       TRUE                2

# %%
from collections import Counter

# Combine tags from tag_1 to tag_9 dynamically
all_tags = []
for index, row in df_en.iterrows():
    tags = []
    for i in range(1, 10):  # Iterate through tag_1 to tag_9
        tag_value = row.get(f"tag_{i}")
        if isinstance(tag_value, str) and pd.notna(tag_value):
            tags.extend(str(tag_value).split())
    all_tags.extend(tags)

# Calculate value counts for the combined tags
tag_counts = Counter(all_tags)
print(tag_counts.most_common(100))
# Out:
# [('Support', 856), ('Technical', 625), ('Issue', 505), ('Service', 467), ('Problem', 404), ('Resolution', 404), ('Urgent', 311), ('IT', 200), ('Product', 194), ('Disruption', 171), ('Guidance', 164), ('System', 132), ('Recovery', 116), ('Network', 114), ('Performance', 110), ('Tuning', 109), ('Software', 109), ('Bug', 109), ('Failure', 103), ('Customer', 101), ('Hardware', 94), ('Maintenance', 94), ('Inquiry', 92), ('Incident', 89), ('Report', 89), ('Account', 76), ('Assistance', 75), ('General', 72), ('Request', 65), ('Notification', 50), ('Billing', 46), ('Crash', 40), ('Outage', 33), ('Warranty', 28), ('Claim', 28), ('Feature', 26), ('Returns', 21), ('and', 21), ('Exchanges', 21), ('Cloud', 20), ('Sales', 20), ('Order', 19), ('Payment', 18), ('Processing', 18), ('Services', 18), ('Documentation', 16), ('Refund', 14), ('Critical', 9), ('Setup', 8), ('Printer', 8), ('Login', 8), ('Feedback', 7), ('Email', 7), ('Cost', 6), ('Optimization', 6), ('Wireless', 5), ('Printing', 5), ('Database', 4), ('Configuration', 4), ('Security', 4), ('Management', 4), ('Replacement', 3), ('Mobile', 3), ('Infrastructure', 3), ('Routine', 3), ('Delay', 3), ('Troubleshooting', 2), ('Human', 2), ('Resources', 2), ('Shipment', 2), ('Settings', 2), ('Duplex', 2), ('Server', 2), ('Improvement', 2), ('Budget', 2), ('Modification', 2), ('Consultation', 2), ('Router', 2), ('Connectivity', 2), ('Consulting', 1), ('Battery', 1), ('Data', 1), ('Breach', 1), ('Backup', 1), ('Restore', 1), ('Password', 1), ('Reset', 1), ('AWS', 1), ('Access', 1), ('Office', 1), ('365', 1), ('Shipping', 1)]

# %%
import re

def should_escalate(incoming_issue):
    if incoming_issue["priority"] == "high":
        # Combine all tags into one string
        tags_combined = " ".join([incoming_issue[f"tag_{i+1}"] for i in range(9)])

        # Keywords that trigger escalation
        keywords = ["Disruption","urgent","issue","refund", "Failure", "Outage", "Incident", "Crash", "Breach", "Critical"]

        # Check if any keyword matches in the combined tags using regular expressions for whole word matching
        for key in keywords:
            if re.search(r'\b' + re.escape(key.lower()) + r'\b', tags_combined.lower()):
                return True

    return False

# %%
def adjust_priority_based_on_severity(incoming_issue):
    severity_keywords = ["Critical", "Emergency", "High"]
    tags_combined = " ".join([incoming_issue[f"tag_{i+1}"] for i in range(9)])

    # Check for severity keywords and adjust priority
    if any(kw.lower() in tags_combined.lower() for kw in severity_keywords):
        if incoming_issue["priority"] == "medium":
            incoming_issue["priority"] = "high"  # Promote priority for urgent keywords

    return incoming_issue

# %%
def escalation_score(incoming_issue):
    tags_combined = " ".join([incoming_issue[f"tag_{i+1}"] for i in range(9)])
    score = sum(1 for key in ["Disruption", "Failure", "Outage", "Incident"] if key.lower() in tags_combined.lower())
    return score

# %%
# Example: Test the escalation function with an incoming issue
incoming_issue = {
    "priority": "high",
    "tag_1": "Failure",
    "tag_2": "Crash",
    "tag_3": "Server",
    "tag_4": "",
    "tag_5": "",
    "tag_6": "",
    "tag_7": "",
    "tag_8": "",
    "tag_9": ""
}

# Check if the issue should be escalated
if should_escalate(incoming_issue):
    print("Escalate the issue")
else:
    print("Do not escalate the issue")

# Adjust priority based on severity (if needed)
incoming_issue = adjust_priority_based_on_severity(incoming_issue)
print(incoming_issue["priority"])

# Calculate escalation score
score = escalation_score(incoming_issue)
print(f"Escalation score: {score}")
# Out:
# Escalate the issue
# high
# Escalation score: 1

# %%
def escalate_all_rows(df):
    """Escalates issues for all rows in the DataFrame based on defined criteria."""

    escalated_rows = []
    for index, row in df.iterrows():
        issue = row.to_dict()
        if should_escalate(issue):
            issue["escalated"] = True  # Add an "escalated" column
            issue = adjust_priority_based_on_severity(issue)
            issue["escalation_score"] = escalation_score(issue)
            escalated_rows.append(issue)
        else:
            issue["escalated"] = False
            issue["escalation_score"] = escalation_score(issue)
            escalated_rows.append(issue)

    return pd.DataFrame(escalated_rows)

# Assuming 'df_en' is your DataFrame (from the previous code)
df_escalated = escalate_all_rows(df_en)

# Convert the DataFrame back to a list of lists for writing to Google Sheets
updated_data = df_escalated.values.tolist()

# Insert headers
header_row = df_escalated.columns.tolist()  # Update header
updated_data.insert(0, header_row)

# Update the Google Sheet with the updated data
try:
    worksheet.update("A1", updated_data)  # Use "A1" to overwrite the entire sheet
    print("Successfully updated Google Sheet with escalated issues.")
except Exception as e:
    print(f"Error updating Google Sheet: {e}")
# Out:
# <ipython-input-15-e9a8dcce67e1>:31: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   worksheet.update("A1", updated_data)  # Use "A1" to overwrite the entire sheet
# Error updating Google Sheet: APIError: [403]: The caller does not have permission

# %%
df = df_escalated
df.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 2  1024619926727    Exchange Request for Malfunctioning Dell XPS 13
# 3  1026487543175       Request for Server Administration Assistance
# 4  1027850274374   Immediate Attention Required: AWS Outage Concern
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 2  Dear Tech Online Store Customer Support,\n\n\n...
# 3  Dear IT Services Customer Support, \n\n\nWe ar...
# 4  Greetings IT Services Customer Support,\n\n\nI...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 2  Dear <name>,\n\n\nThank you for reaching out a...    Change
# 3  Subject: Re: Request for Server Administration...   Request
# 4  Hello <name>,\n\n\nWe appreciate you informing...  Incident
#
#                    queue priority language      business_type  \
# 0      Technical Support     high       en        IT Services
# 1        Product Support      low       en  Tech Online Store
# 2  Returns and Exchanges   medium       en  Tech Online Store
# 3        Product Support   medium       en        IT Services
# 4      Technical Support     high       en        IT Services
#
#                    tag_1                tag_2               tag_3  \
# 0         Service Outage        Network Issue        Urgent Issue
# 1      Technical Support      Product Support    Hardware Failure
# 2  Returns and Exchanges  Product Replacement    Customer Service
# 3      Technical Support           IT Support  Performance Tuning
# 4         Service Outage         Urgent Issue          IT Support
#
#                 tag_4               tag_5             tag_6  \
# 0   Technical Support  Problem Resolution  Critical Failure
# 1  Problem Resolution        Urgent Issue  Service Recovery
# 2   Technical Support         Order Issue
# 3  Problem Resolution  Technical Guidance  Service Recovery
# 4  System Maintenance     Incident Report  Customer Service
#
#                    tag_7               tag_8 tag_9  escalated  \
# 0           System Crash  Service Disruption             True
# 1  Documentation Request                                False
# 2                                                       False
# 3                                                       False
# 4                                                        True
#
#    escalation_score
# 0                 3
# 1                 1
# 2                 0
# 3                 0
# 4                 2

# %%
import requests
import json

def escalate_issue(issue_data, api_endpoint):
    """
    Sends a POST request to the /check_escalate API endpoint to escalate an issue.

    Args:
        issue_data (dict): A dictionary containing the issue data.
        api_endpoint (str): The URL of the /check_escalate API endpoint.

    Returns:
        dict: The JSON response from the API, or None if there was an error.
    """
    try:
        headers = {'Content-type': 'application/json'}  # Set the content type to JSON
        response = requests.post(api_endpoint, data=json.dumps(issue_data), headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

        return response.json()

    except requests.exceptions.RequestException as e:
        print(f"Error escalating issue: {e}")
        return None

# Example Usage (replace with your actual API endpoint and issue data)
api_url = "/content/code.txt"

# Assuming 'df_escalated' is your DataFrame with the 'escalated' column (from the previous code)

for index, row in df_escalated.iterrows():
    if row['escalated']:
        issue_data = row.to_dict()  # Convert the row to a dictionary
        escalation_response = escalate_issue(issue_data, api_url)

        if escalation_response:
            print(f"Escalation successful for issue {index}: {escalation_response}")
        else:
            print(f"Escalation failed for issue {index}")
# Out:
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 0
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 4
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 5
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 7
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 10
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 12
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 17
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 18
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 19
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 21
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 24
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 26
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 33
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 34
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 39
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 41
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 45
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 46
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 49
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 51
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 52
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 53
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 55
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 58
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 65
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 66
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 67
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 70
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 72
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 73
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 74
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 75
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 77
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 78
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 79
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 80
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 83
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 87
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 91
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 93
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 95
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 100
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 101
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 104
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 111
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 112
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 113
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 114
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 115
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 116
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 117
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 121
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 122
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 123
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 128
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 133
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 134
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 137
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 138
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 139
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 143
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 145
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 152
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 153
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 154
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 155
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 158
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 160
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 163
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 167
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 169
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 170
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 177
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 179
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 180
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 181
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 182
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 190
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 192
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 193
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 194
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 195
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 196
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 198
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 199
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 200
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 202
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 204
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 208
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 209
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 210
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 212
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 213
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 214
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 215
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 217
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 219
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 220
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 221
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 222
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 224
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 225
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 226
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 227
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 228
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 234
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 236
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 240
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 243
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 245
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 247
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 250
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 251
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 252
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 253
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 254
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 255
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 256
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 258
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 259
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 263
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 268
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 269
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 273
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 274
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 276
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 277
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 279
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 280
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 281
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 286
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 289
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 291
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 293
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 296
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 299
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 300
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 301
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 303
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 306
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 307
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 309
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 310
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 311
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 313
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 315
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 316
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 318
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 321
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 322
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 323
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 327
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 328
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 329
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 330
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 332
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 334
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 335
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 336
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 338
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 341
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 346
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 347
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 350
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 351
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 352
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 356
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 358
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 365
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 366
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 367
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 368
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 371
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 373
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 376
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 380
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 382
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 383
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 390
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 392
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 393
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 394
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 395
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 403
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 405
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 406
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 407
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 408
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 409
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 411
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 412
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 413
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 415
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 417
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 421
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 422
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 423
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 425
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 426
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 427
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 428
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 430
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 432
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 433
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 434
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 435
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 437
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 438
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 439
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 440
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 441
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 447
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 449
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 453
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 456
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 458
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 460
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 463
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 464
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 465
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 466
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 467
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 468
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 469
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 471
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 472
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 476
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 481
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 482
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 486
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 487
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 489
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 490
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 492
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 493
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 494
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 499
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 502
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 504
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 506
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 509
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 512
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 513
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 514
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 516
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 519
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 520
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 522
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 523
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 524
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 526
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 528
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 529
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 531
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 534
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 535
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 536
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 540
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 541
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 542
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 543
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 545
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 547
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 548
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 549
# Error escalating issue: Invalid URL '/content/code.txt': No scheme supplied. Perhaps you meant https:///content/code.txt?
# Escalation failed for issue 551
